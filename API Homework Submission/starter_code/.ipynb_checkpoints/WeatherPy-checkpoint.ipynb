# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# # Analysis
# Observed Trend 1: When comparing the latitude vs. maximum temperature, and considering that the Northern Hemisphere is currently in its summer months, the data shows that there is a positive correlation between the latitude and maximum temperature.
#
# Observed Trend 2:
# Observed Trend 3:

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
total_cities=len(cities)
total_cities
# Out:
# 610

# %%
# cities

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
#set up lists to hold response info
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
counter=0


# Get weather data by looping through each city and skipping cities not found
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        counter= counter+1
        print(f"Processing Record number {counter} of {total_cities}  | {city}")
        city_name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        
    except KeyError:
        print(f"City not found. Skipping...")

print('-----------------------------')
print('Data Retrieval Complete ')     
print('-----------------------------')
# Out:
# Processing Record number 1 of 610  | lebu
# Processing Record number 2 of 610  | kavaratti
# Processing Record number 3 of 610  | strelka
# Processing Record number 4 of 610  | cabo san lucas
# Processing Record number 5 of 610  | hobart
# Processing Record number 6 of 610  | yinchuan
# Processing Record number 7 of 610  | hasaki
# Processing Record number 8 of 610  | bredasdorp
# Processing Record number 9 of 610  | ushuaia
# Processing Record number 10 of 610  | cape town
# Processing Record number 11 of 610  | mataura
# Processing Record number 12 of 610  | albany
# Processing Record number 13 of 610  | unye
# City not found. Skipping...
# Processing Record number 14 of 610  | kapaa
# Processing Record number 15 of 610  | alice springs
# Processing Record number 16 of 610  | geraldton
# Processing Record number 17 of 610  | saint-philippe
# Processing Record number 18 of 610  | attawapiskat
# City not found. Skipping...
# Processing Record number 19 of 610  | hermanus
# Processing Record number 20 of 610  | gibsons
# Processing Record number 21 of 610  | barentsburg
# City not found. Skipping...
# Processing Record number 22 of 610  | bengkulu
# City not found. Skipping...
# Processing Record number 23 of 610  | atuona
# Processing Record number 24 of 610  | taolanaro
# City not found. Skipping...
# Processing Record number 25 of 610  | omaruru
# Processing Record number 26 of 610  | jamestown
# Processing Record number 27 of 610  | la rioja
# Processing Record number 28 of 610  | maghama
# City not found. Skipping...
# Processing Record number 29 of 610  | butaritari
# Processing Record number 30 of 610  | chapais
# Processing Record number 31 of 610  | boende
# Processing Record number 32 of 610  | mizan teferi
# Processing Record number 33 of 610  | ksenyevka
# City not found. Skipping...
# Processing Record number 34 of 610  | tabuk
# Processing Record number 35 of 610  | barbar
# City not found. Skipping...
# Processing Record number 36 of 610  | grand gaube
# Processing Record number 37 of 610  | bandarbeyla
# Processing Record number 38 of 610  | paamiut
# Processing Record number 39 of 610  | punta arenas
# Processing Record number 40 of 610  | verkhnevilyuysk
# Processing Record number 41 of 610  | mount gambier
# Processing Record number 42 of 610  | kidal
# Processing Record number 43 of 610  | ponta do sol
# Processing Record number 44 of 610  | paraopeba
# Processing Record number 45 of 610  | port alfred
# Processing Record number 46 of 610  | chicama
# Processing Record number 47 of 610  | herat
# Processing Record number 48 of 610  | mazatlan
# Processing Record number 49 of 610  | qaqortoq
# Processing Record number 50 of 610  | san cristobal
# Processing Record number 51 of 610  | yellowknife
# Processing Record number 52 of 610  | alofi
# Processing Record number 53 of 610  | richards bay
# Processing Record number 54 of 610  | puerto narino
# Processing Record number 55 of 610  | ariquemes
# Processing Record number 56 of 610  | belushya guba
# City not found. Skipping...
# Processing Record number 57 of 610  | lagoa
# Processing Record number 58 of 610  | rikitea
# Processing Record number 59 of 610  | providencia
# Processing Record number 60 of 610  | lourical
# Processing Record number 61 of 610  | vaini
# Processing Record number 62 of 610  | kuryk
# Processing Record number 63 of 610  | illoqqortoormiut
# City not found. Skipping...
# Processing Record number 64 of 610  | qaanaaq
# Processing Record number 65 of 610  | tasiilaq
# Processing Record number 66 of 610  | waitara
# Processing Record number 67 of 610  | faya
# Processing Record number 68 of 610  | jalu
# Processing Record number 69 of 610  | mar del plata
# Processing Record number 70 of 610  | port-gentil
# Processing Record number 71 of 610  | new norfolk
# Processing Record number 72 of 610  | ribeira grande
# Processing Record number 73 of 610  | ovsyanka
# Processing Record number 74 of 610  | busselton
# Processing Record number 75 of 610  | tuktoyaktuk
# Processing Record number 76 of 610  | turukhansk
# Processing Record number 77 of 610  | itaporanga
# Processing Record number 78 of 610  | paiho
# City not found. Skipping...
# Processing Record number 79 of 610  | evansville
# Processing Record number 80 of 610  | phan thiet
# Processing Record number 81 of 610  | araguaina
# Processing Record number 82 of 610  | bambous virieux
# Processing Record number 83 of 610  | nanortalik
# Processing Record number 84 of 610  | kendari
# Processing Record number 85 of 610  | bucerias
# Processing Record number 86 of 610  | santa maria da boa vista
# Processing Record number 87 of 610  | tambul
# City not found. Skipping...
# Processing Record number 88 of 610  | kodiak
# Processing Record number 89 of 610  | longlac
# City not found. Skipping...
# Processing Record number 90 of 610  | santa rosa
# Processing Record number 91 of 610  | luorong
# Processing Record number 92 of 610  | chulman
# Processing Record number 93 of 610  | walvis bay
# Processing Record number 94 of 610  | amderma
# City not found. Skipping...
# Processing Record number 95 of 610  | port blair
# Processing Record number 96 of 610  | alexandria
# Processing Record number 97 of 610  | soe
# Processing Record number 98 of 610  | hervey bay
# Processing Record number 99 of 610  | tsihombe
# City not found. Skipping...
# Processing Record number 100 of 610  | norman wells
# Processing Record number 101 of 610  | thompson
# Processing Record number 102 of 610  | avarua
# Processing Record number 103 of 610  | normandin
# Processing Record number 104 of 610  | filadelfia
# Processing Record number 105 of 610  | ichinoseki
# Processing Record number 106 of 610  | kaitangata
# Processing Record number 107 of 610  | nikolskoye
# Processing Record number 108 of 610  | torbay
# Processing Record number 109 of 610  | vestmannaeyjar
# Processing Record number 110 of 610  | barrow
# Processing Record number 111 of 610  | mezhdurechensk
# Processing Record number 112 of 610  | tuatapere
# Processing Record number 113 of 610  | tecoanapa
# Processing Record number 114 of 610  | tsabong
# Processing Record number 115 of 610  | la romana
# Processing Record number 116 of 610  | carnarvon
# Processing Record number 117 of 610  | puerto ayora
# Processing Record number 118 of 610  | provideniya
# Processing Record number 119 of 610  | nortelandia
# Processing Record number 120 of 610  | hilo
# Processing Record number 121 of 610  | chuy
# Processing Record number 122 of 610  | sentyabrskiy
# City not found. Skipping...
# Processing Record number 123 of 610  | silver city
# Processing Record number 124 of 610  | sibu
# Processing Record number 125 of 610  | tiznit
# Processing Record number 126 of 610  | karratha
# Processing Record number 127 of 610  | hengyang
# Processing Record number 128 of 610  | mushie
# Processing Record number 129 of 610  | faanui
# Processing Record number 130 of 610  | hami
# Processing Record number 131 of 610  | vaitupu
# City not found. Skipping...
# Processing Record number 132 of 610  | guerrero negro
# Processing Record number 133 of 610  | mayo
# Processing Record number 134 of 610  | cabatuan
# Processing Record number 135 of 610  | okhotsk
# Processing Record number 136 of 610  | bluff
# Processing Record number 137 of 610  | concarneau
# Processing Record number 138 of 610  | zhigansk
# Processing Record number 139 of 610  | dalbandin
# Processing Record number 140 of 610  | nouakchott
# Processing Record number 141 of 610  | ilulissat
# Processing Record number 142 of 610  | pemba
# Processing Record number 143 of 610  | leningradskiy
# Processing Record number 144 of 610  | matara
# Processing Record number 145 of 610  | chifeng
# Processing Record number 146 of 610  | pangody
# Processing Record number 147 of 610  | lompoc
# Processing Record number 148 of 610  | niquelandia
# Processing Record number 149 of 610  | baykit
# Processing Record number 150 of 610  | hurricane
# Processing Record number 151 of 610  | vila velha
# Processing Record number 152 of 610  | santiago del estero
# Processing Record number 153 of 610  | berdigestyakh
# Processing Record number 154 of 610  | ostrovnoy
# Processing Record number 155 of 610  | mnogovershinnyy
# Processing Record number 156 of 610  | grao mogol
# City not found. Skipping...
# Processing Record number 157 of 610  | komsomolskiy
# Processing Record number 158 of 610  | hithadhoo
# Processing Record number 159 of 610  | sambava
# Processing Record number 160 of 610  | tiksi
# Processing Record number 161 of 610  | surok
# Processing Record number 162 of 610  | margate
# Processing Record number 163 of 610  | abha
# Processing Record number 164 of 610  | acapulco
# Processing Record number 165 of 610  | sao joao da barra
# Processing Record number 166 of 610  | arraial do cabo
# Processing Record number 167 of 610  | vila
# Processing Record number 168 of 610  | cherdyn
# Processing Record number 169 of 610  | mapiri
# Processing Record number 170 of 610  | pokhara
# Processing Record number 171 of 610  | castro
# Processing Record number 172 of 610  | souillac
# Processing Record number 173 of 610  | melfort
# Processing Record number 174 of 610  | sawakin
# Processing Record number 175 of 610  | tongliao
# Processing Record number 176 of 610  | vrangel
# Processing Record number 177 of 610  | noumea
# Processing Record number 178 of 610  | magadan
# Processing Record number 179 of 610  | cortland
# Processing Record number 180 of 610  | borovskoy
# Processing Record number 181 of 610  | upernavik
# Processing Record number 182 of 610  | bourail
# Processing Record number 183 of 610  | khatanga
# Processing Record number 184 of 610  | hobyo
# Processing Record number 185 of 610  | olinda
# Processing Record number 186 of 610  | pangnirtung
# Processing Record number 187 of 610  | saint george
# Processing Record number 188 of 610  | urumqi
# City not found. Skipping...
# Processing Record number 189 of 610  | la carolina
# Processing Record number 190 of 610  | phitsanulok
# Processing Record number 191 of 610  | salalah
# Processing Record number 192 of 610  | iqaluit
# Processing Record number 193 of 610  | comodoro rivadavia
# Processing Record number 194 of 610  | zachary
# Processing Record number 195 of 610  | nago
# Processing Record number 196 of 610  | malakal
# City not found. Skipping...
# Processing Record number 197 of 610  | kadipaten
# Processing Record number 198 of 610  | tripoli
# Processing Record number 199 of 610  | coahuayana
# Processing Record number 200 of 610  | victoria
# Processing Record number 201 of 610  | cidreira
# Processing Record number 202 of 610  | pandegelang
# Processing Record number 203 of 610  | high level
# Processing Record number 204 of 610  | kaura namoda
# Processing Record number 205 of 610  | la ronge
# Processing Record number 206 of 610  | georgetown
# Processing Record number 207 of 610  | camana
# City not found. Skipping...
# Processing Record number 208 of 610  | laharpur
# Processing Record number 209 of 610  | ilebo
# Processing Record number 210 of 610  | talcahuano
# Processing Record number 211 of 610  | pevek
# Processing Record number 212 of 610  | sitka
# Processing Record number 213 of 610  | el alto
# Processing Record number 214 of 610  | vila franca do campo
# Processing Record number 215 of 610  | husavik
# Processing Record number 216 of 610  | jucas
# Processing Record number 217 of 610  | narsaq
# Processing Record number 218 of 610  | itarema
# Processing Record number 219 of 610  | cherskiy
# Processing Record number 220 of 610  | morgan city
# Processing Record number 221 of 610  | malmyzh
# Processing Record number 222 of 610  | san antonio
# Processing Record number 223 of 610  | tadine
# Processing Record number 224 of 610  | samarai
# Processing Record number 225 of 610  | cururupu
# Processing Record number 226 of 610  | fairbanks
# Processing Record number 227 of 610  | cedral
# Processing Record number 228 of 610  | muisne
# Processing Record number 229 of 610  | panama city
# Processing Record number 230 of 610  | kurilsk
# Processing Record number 231 of 610  | mashhad
# Processing Record number 232 of 610  | morro bay
# Processing Record number 233 of 610  | vila do maio
# Processing Record number 234 of 610  | zhanaozen
# Processing Record number 235 of 610  | avera
# Processing Record number 236 of 610  | svetlogorsk
# Processing Record number 237 of 610  | saint-francois
# Processing Record number 238 of 610  | key west
# Processing Record number 239 of 610  | terney
# Processing Record number 240 of 610  | hammerfest
# Processing Record number 241 of 610  | moyamba
# Processing Record number 242 of 610  | tilichiki
# Processing Record number 243 of 610  | diffa
# Processing Record number 244 of 610  | sakakah
# City not found. Skipping...
# Processing Record number 245 of 610  | turbiv
# Processing Record number 246 of 610  | conakry
# Processing Record number 247 of 610  | batemans bay
# Processing Record number 248 of 610  | severo-kurilsk
# Processing Record number 249 of 610  | krasnyy chikoy
# Processing Record number 250 of 610  | nizhneyansk
# City not found. Skipping...
# Processing Record number 251 of 610  | cayenne
# Processing Record number 252 of 610  | valparaiso
# Processing Record number 253 of 610  | marcona
# City not found. Skipping...
# Processing Record number 254 of 610  | clyde river
# Processing Record number 255 of 610  | honningsvag
# Processing Record number 256 of 610  | neuquen
# Processing Record number 257 of 610  | rio grande
# Processing Record number 258 of 610  | pontianak
# Processing Record number 259 of 610  | xuddur
# Processing Record number 260 of 610  | codrington
# Processing Record number 261 of 610  | villa oliva
# City not found. Skipping...
# Processing Record number 262 of 610  | anadyr
# Processing Record number 263 of 610  | hualmay
# Processing Record number 264 of 610  | baracoa
# Processing Record number 265 of 610  | nambucca heads
# Processing Record number 266 of 610  | nioro
# Processing Record number 267 of 610  | liverpool
# Processing Record number 268 of 610  | saskylakh
# Processing Record number 269 of 610  | sao gabriel
# Processing Record number 270 of 610  | beringovskiy
# Processing Record number 271 of 610  | cananeia
# Processing Record number 272 of 610  | grand forks
# Processing Record number 273 of 610  | labuhan
# Processing Record number 274 of 610  | wajima
# Processing Record number 275 of 610  | ijaki
# City not found. Skipping...
# Processing Record number 276 of 610  | metro
# Processing Record number 277 of 610  | chokurdakh
# Processing Record number 278 of 610  | vardo
# Processing Record number 279 of 610  | dikson
# Processing Record number 280 of 610  | fortuna
# Processing Record number 281 of 610  | kudahuvadhoo
# Processing Record number 282 of 610  | menongue
# Processing Record number 283 of 610  | cockburn town
# Processing Record number 284 of 610  | egvekinot
# Processing Record number 285 of 610  | tulle
# Processing Record number 286 of 610  | stanger
# Processing Record number 287 of 610  | tarakan
# Processing Record number 288 of 610  | roald
# Processing Record number 289 of 610  | emmett
# Processing Record number 290 of 610  | lata
# Processing Record number 291 of 610  | maketu
# Processing Record number 292 of 610  | roma
# Processing Record number 293 of 610  | talara
# Processing Record number 294 of 610  | opuwo
# Processing Record number 295 of 610  | prainha
# Processing Record number 296 of 610  | ugoofaaru
# Processing Record number 297 of 610  | dubbo
# Processing Record number 298 of 610  | kavieng
# Processing Record number 299 of 610  | mathbaria
# Processing Record number 300 of 610  | bethel
# Processing Record number 301 of 610  | miraflores
# Processing Record number 302 of 610  | maceio
# Processing Record number 303 of 610  | mgandu
# Processing Record number 304 of 610  | amarpur
# Processing Record number 305 of 610  | jiangkou
# Processing Record number 306 of 610  | hofn
# Processing Record number 307 of 610  | esperance
# Processing Record number 308 of 610  | nelson bay
# Processing Record number 309 of 610  | havelock
# Processing Record number 310 of 610  | zhezkazgan
# Processing Record number 311 of 610  | luderitz
# Processing Record number 312 of 610  | sao felix do xingu
# Processing Record number 313 of 610  | lingyuan
# Processing Record number 314 of 610  | bowen
# Processing Record number 315 of 610  | shakhtinsk
# Processing Record number 316 of 610  | flinders
# Processing Record number 317 of 610  | pemangkat
# City not found. Skipping...
# Processing Record number 318 of 610  | grand river south east
# City not found. Skipping...
# Processing Record number 319 of 610  | khakhea
# Processing Record number 320 of 610  | palmer
# Processing Record number 321 of 610  | mount isa
# Processing Record number 322 of 610  | abu jubayhah
# City not found. Skipping...
# Processing Record number 323 of 610  | one hundred mile house
# City not found. Skipping...
# Processing Record number 324 of 610  | solnechnyy
# Processing Record number 325 of 610  | fenoarivo
# Processing Record number 326 of 610  | oga
# Processing Record number 327 of 610  | makaryev
# Processing Record number 328 of 610  | marystown
# Processing Record number 329 of 610  | sirvintos
# Processing Record number 330 of 610  | zyryanka
# Processing Record number 331 of 610  | buala
# Processing Record number 332 of 610  | klaksvik
# Processing Record number 333 of 610  | sherbakul
# Processing Record number 334 of 610  | jovellar
# Processing Record number 335 of 610  | bathsheba
# Processing Record number 336 of 610  | palabuhanratu
# City not found. Skipping...
# Processing Record number 337 of 610  | mahebourg
# Processing Record number 338 of 610  | ladyzhyn
# Processing Record number 339 of 610  | mehran
# Processing Record number 340 of 610  | meinung
# City not found. Skipping...
# Processing Record number 341 of 610  | puerto escondido
# Processing Record number 342 of 610  | katsuura
# Processing Record number 343 of 610  | almaznyy
# Processing Record number 344 of 610  | orange walk
# Processing Record number 345 of 610  | sibolga
# Processing Record number 346 of 610  | matamoros
# Processing Record number 347 of 610  | grand-santi
# Processing Record number 348 of 610  | srednekolymsk
# Processing Record number 349 of 610  | moose factory
# Processing Record number 350 of 610  | kenai
# Processing Record number 351 of 610  | laguna
# Processing Record number 352 of 610  | monticello
# Processing Record number 353 of 610  | pangkalanbuun
# Processing Record number 354 of 610  | lavrentiya
# Processing Record number 355 of 610  | college
# Processing Record number 356 of 610  | taonan
# Processing Record number 357 of 610  | plattsburgh
# Processing Record number 358 of 610  | pandrup
# Processing Record number 359 of 610  | tual
# Processing Record number 360 of 610  | raga
# City not found. Skipping...
# Processing Record number 361 of 610  | grants
# Processing Record number 362 of 610  | ystad
# Processing Record number 363 of 610  | port elizabeth
# Processing Record number 364 of 610  | sangar
# Processing Record number 365 of 610  | banjar
# Processing Record number 366 of 610  | lasa
# Processing Record number 367 of 610  | bay roberts
# Processing Record number 368 of 610  | quelimane
# Processing Record number 369 of 610  | grindavik
# Processing Record number 370 of 610  | manicore
# Processing Record number 371 of 610  | armenia
# Processing Record number 372 of 610  | namatanai
# Processing Record number 373 of 610  | el limon
# Processing Record number 374 of 610  | pinan
# Processing Record number 375 of 610  | santa catarina de tepehuanes
# Processing Record number 376 of 610  | buraydah
# Processing Record number 377 of 610  | sabang
# Processing Record number 378 of 610  | karamea
# City not found. Skipping...
# Processing Record number 379 of 610  | tabou
# Processing Record number 380 of 610  | porto novo
# Processing Record number 381 of 610  | miyako
# Processing Record number 382 of 610  | porbandar
# Processing Record number 383 of 610  | airai
# Processing Record number 384 of 610  | constitucion
# Processing Record number 385 of 610  | barcelos
# Processing Record number 386 of 610  | port macquarie
# Processing Record number 387 of 610  | bilma
# Processing Record number 388 of 610  | nchelenge
# Processing Record number 389 of 610  | north bend
# Processing Record number 390 of 610  | ahipara
# Processing Record number 391 of 610  | christchurch
# Processing Record number 392 of 610  | urusha
# Processing Record number 393 of 610  | maningrida
# Processing Record number 394 of 610  | capoterra
# Processing Record number 395 of 610  | vao
# Processing Record number 396 of 610  | lakes entrance
# Processing Record number 397 of 610  | nalvo
# Processing Record number 398 of 610  | yar-sale
# Processing Record number 399 of 610  | vilcun
# Processing Record number 400 of 610  | wanning
# Processing Record number 401 of 610  | galle
# Processing Record number 402 of 610  | honiara
# Processing Record number 403 of 610  | pafos
# City not found. Skipping...
# Processing Record number 404 of 610  | goderich
# Processing Record number 405 of 610  | ketchikan
# Processing Record number 406 of 610  | dingle
# Processing Record number 407 of 610  | rundu
# Processing Record number 408 of 610  | gbadolite
# Processing Record number 409 of 610  | wladyslawowo
# Processing Record number 410 of 610  | waipawa
# Processing Record number 411 of 610  | quang ngai
# Processing Record number 412 of 610  | zomba
# Processing Record number 413 of 610  | khor
# Processing Record number 414 of 610  | saint-pierre
# Processing Record number 415 of 610  | kutulik
# Processing Record number 416 of 610  | ust-barguzin
# Processing Record number 417 of 610  | ginir
# Processing Record number 418 of 610  | ampanihy
# Processing Record number 419 of 610  | dunedin
# Processing Record number 420 of 610  | aykhal
# Processing Record number 421 of 610  | lac du bonnet
# Processing Record number 422 of 610  | satuk
# Processing Record number 423 of 610  | partapur
# Processing Record number 424 of 610  | pochutla
# Processing Record number 425 of 610  | sao filipe
# Processing Record number 426 of 610  | caravelas
# Processing Record number 427 of 610  | east london
# Processing Record number 428 of 610  | assiniboia
# Processing Record number 429 of 610  | ayan
# Processing Record number 430 of 610  | thiadiaye
# Processing Record number 431 of 610  | da nang
# City not found. Skipping...
# Processing Record number 432 of 610  | ust-maya
# Processing Record number 433 of 610  | dessau
# Processing Record number 434 of 610  | whitefish
# Processing Record number 435 of 610  | fierze
# City not found. Skipping...
# Processing Record number 436 of 610  | sechura
# Processing Record number 437 of 610  | adrar
# Processing Record number 438 of 610  | haibowan
# City not found. Skipping...
# Processing Record number 439 of 610  | crowley
# Processing Record number 440 of 610  | port lincoln
# Processing Record number 441 of 610  | beyneu
# Processing Record number 442 of 610  | kloulklubed
# Processing Record number 443 of 610  | gorin
# Processing Record number 444 of 610  | vasteras
# Processing Record number 445 of 610  | saint-georges
# Processing Record number 446 of 610  | mys shmidta
# City not found. Skipping...
# Processing Record number 447 of 610  | sao jose da coroa grande
# Processing Record number 448 of 610  | hirara
# Processing Record number 449 of 610  | brae
# Processing Record number 450 of 610  | merauke
# Processing Record number 451 of 610  | yerbogachen
# Processing Record number 452 of 610  | kamenka
# Processing Record number 453 of 610  | abu zabad
# Processing Record number 454 of 610  | belmonte
# Processing Record number 455 of 610  | banda aceh
# Processing Record number 456 of 610  | korla
# City not found. Skipping...
# Processing Record number 457 of 610  | sinnamary
# Processing Record number 458 of 610  | vaitape
# Processing Record number 459 of 610  | haines junction
# Processing Record number 460 of 610  | zhangye
# Processing Record number 461 of 610  | gamba
# Processing Record number 462 of 610  | nikolayevka
# Processing Record number 463 of 610  | remontnoye
# Processing Record number 464 of 610  | dianopolis
# City not found. Skipping...
# Processing Record number 465 of 610  | san jeronimo
# Processing Record number 466 of 610  | yumen
# Processing Record number 467 of 610  | tanout
# Processing Record number 468 of 610  | plettenberg bay
# Processing Record number 469 of 610  | rocha
# Processing Record number 470 of 610  | ust-kamchatsk
# City not found. Skipping...
# Processing Record number 471 of 610  | coro
# Processing Record number 472 of 610  | oriximina
# Processing Record number 473 of 610  | maloshuyka
# City not found. Skipping...
# Processing Record number 474 of 610  | ewa beach
# Processing Record number 475 of 610  | samoded
# Processing Record number 476 of 610  | srandakan
# Processing Record number 477 of 610  | milton
# Processing Record number 478 of 610  | tuggurt
# City not found. Skipping...
# Processing Record number 479 of 610  | neepawa
# Processing Record number 480 of 610  | charters towers
# Processing Record number 481 of 610  | dharchula
# Processing Record number 482 of 610  | tangjiazhuang
# Processing Record number 483 of 610  | alcudia
# Processing Record number 484 of 610  | nyurba
# Processing Record number 485 of 610  | coos bay
# Processing Record number 486 of 610  | sovetskiy
# Processing Record number 487 of 610  | rorvik
# Processing Record number 488 of 610  | morehead
# Processing Record number 489 of 610  | leh
# Processing Record number 490 of 610  | kaoma
# Processing Record number 491 of 610  | teacapan
# Processing Record number 492 of 610  | dryden
# Processing Record number 493 of 610  | vidisha
# Processing Record number 494 of 610  | kiunga
# Processing Record number 495 of 610  | bakel
# Processing Record number 496 of 610  | matsanga
# City not found. Skipping...
# Processing Record number 497 of 610  | chavannes
# Processing Record number 498 of 610  | iquique
# Processing Record number 499 of 610  | kotelnich
# Processing Record number 500 of 610  | elblag
# Processing Record number 501 of 610  | tasbuget
# City not found. Skipping...
# Processing Record number 502 of 610  | batyrevo
# Processing Record number 503 of 610  | mvomero
# Processing Record number 504 of 610  | bargal
# City not found. Skipping...
# Processing Record number 505 of 610  | cardston
# Processing Record number 506 of 610  | ciudad del maiz
# Processing Record number 507 of 610  | zambezi
# Processing Record number 508 of 610  | vylkove
# Processing Record number 509 of 610  | tazovskiy
# Processing Record number 510 of 610  | lakselv
# Processing Record number 511 of 610  | hamilton
# Processing Record number 512 of 610  | mackenzie
# Processing Record number 513 of 610  | carmen
# Processing Record number 514 of 610  | aykino
# Processing Record number 515 of 610  | sabya
# Processing Record number 516 of 610  | palmerston
# Processing Record number 517 of 610  | flin flon
# Processing Record number 518 of 610  | galiwinku
# City not found. Skipping...
# Processing Record number 519 of 610  | morondava
# Processing Record number 520 of 610  | umm kaddadah
# Processing Record number 521 of 610  | pisco
# Processing Record number 522 of 610  | kruisfontein
# Processing Record number 523 of 610  | talnakh
# Processing Record number 524 of 610  | mareeba
# Processing Record number 525 of 610  | te anau
# Processing Record number 526 of 610  | realeza
# Processing Record number 527 of 610  | okato
# Processing Record number 528 of 610  | kathu
# Processing Record number 529 of 610  | sur
# Processing Record number 530 of 610  | matanzas
# Processing Record number 531 of 610  | harper
# Processing Record number 532 of 610  | oranjemund
# Processing Record number 533 of 610  | coihaique
# Processing Record number 534 of 610  | lazo
# Processing Record number 535 of 610  | mehamn
# Processing Record number 536 of 610  | kysyl-syr
# Processing Record number 537 of 610  | tago
# Processing Record number 538 of 610  | viligili
# City not found. Skipping...
# Processing Record number 539 of 610  | gladstone
# Processing Record number 540 of 610  | polunochnoye
# Processing Record number 541 of 610  | saint anthony
# Processing Record number 542 of 610  | calama
# Processing Record number 543 of 610  | monrovia
# Processing Record number 544 of 610  | alice town
# Processing Record number 545 of 610  | gao
# Processing Record number 546 of 610  | puerto baquerizo moreno
# Processing Record number 547 of 610  | seoul
# Processing Record number 548 of 610  | samusu
# City not found. Skipping...
# Processing Record number 549 of 610  | mirante do paranapanema
# Processing Record number 550 of 610  | hohhot
# Processing Record number 551 of 610  | kirovskiy
# Processing Record number 552 of 610  | bac lieu
# City not found. Skipping...
# Processing Record number 553 of 610  | meiktila
# Processing Record number 554 of 610  | atar
# Processing Record number 555 of 610  | socorro
# Processing Record number 556 of 610  | alamogordo
# Processing Record number 557 of 610  | saquena
# Processing Record number 558 of 610  | san blas
# Processing Record number 559 of 610  | langfang
# Processing Record number 560 of 610  | orange cove
# Processing Record number 561 of 610  | santa isabel do rio negro
# Processing Record number 562 of 610  | yeppoon
# Processing Record number 563 of 610  | lorengau
# Processing Record number 564 of 610  | dauriya
# Processing Record number 565 of 610  | dolbeau
# City not found. Skipping...
# Processing Record number 566 of 610  | aqtobe
# Processing Record number 567 of 610  | ucluelet
# Processing Record number 568 of 610  | kamyshin
# Processing Record number 569 of 610  | artyom
# Processing Record number 570 of 610  | mahajanga
# Processing Record number 571 of 610  | longyearbyen
# Processing Record number 572 of 610  | uwayl
# City not found. Skipping...
# Processing Record number 573 of 610  | lucapa
# Processing Record number 574 of 610  | porto walter
# Processing Record number 575 of 610  | pauini
# Processing Record number 576 of 610  | novyy urengoy
# Processing Record number 577 of 610  | ancud
# Processing Record number 578 of 610  | padang
# Processing Record number 579 of 610  | ixtapa
# Processing Record number 580 of 610  | ola
# Processing Record number 581 of 610  | petapa
# City not found. Skipping...
# Processing Record number 582 of 610  | ilhabela
# Processing Record number 583 of 610  | aswan
# Processing Record number 584 of 610  | saldanha
# Processing Record number 585 of 610  | kanniyakumari
# Processing Record number 586 of 610  | sulangan
# Processing Record number 587 of 610  | arcos de la frontera
# Processing Record number 588 of 610  | grand falls
# Processing Record number 589 of 610  | aquiraz
# Processing Record number 590 of 610  | machali
# City not found. Skipping...
# Processing Record number 591 of 610  | bonthe
# Processing Record number 592 of 610  | callaway
# Processing Record number 593 of 610  | santo antonio da platina
# Processing Record number 594 of 610  | beira
# Processing Record number 595 of 610  | nador
# Processing Record number 596 of 610  | gombong
# Processing Record number 597 of 610  | takestan
# Processing Record number 598 of 610  | yenagoa
# Processing Record number 599 of 610  | westport
# Processing Record number 600 of 610  | uray
# Processing Record number 601 of 610  | meulaboh
# Processing Record number 602 of 610  | urkut
# Processing Record number 603 of 610  | arandis
# Processing Record number 604 of 610  | mlimba
# Processing Record number 605 of 610  | mutsamudu
# City not found. Skipping...
# Processing Record number 606 of 610  | karkaralinsk
# City not found. Skipping...
# Processing Record number 607 of 610  | burnie
# Processing Record number 608 of 610  | beloha
# Processing Record number 609 of 610  | kieta
# Processing Record number 610 of 610  | mustla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dataframe to hold results
summary_df = pd.DataFrame({"City": city_name,
                           "Cloudiness": cloudiness,
                           "Country": country,
                           "Date": date,
                            "Humidity": humidity,   
                            "Lat": lat,
                           "Lng": lng,
                           "Max Temp": max_temp,
                           "Wind Speed": wind_speed})

# %%
summary_df.count()
# Out:
# City          553
# Cloudiness    553
# Country       553
# Date          553
# Humidity      553
# Lat           553
# Lng           553
# Max Temp      553
# Wind Speed    553
# dtype: int64

# %%
summary_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0            Lebu          75      ET  1566434840        87   8.96   38.73
# 1       Kavaratti         100      IN  1566434841        75  10.57   72.64
# 2         Strelka           0      RU  1566434841        96  58.08   93.03
# 3  Cabo San Lucas          40      MX  1566434646        70  22.89 -109.91
# 4          Hobart          20      AU  1566434712        79 -42.88  147.33
#
#    Max Temp  Wind Speed
# 0     59.00        4.70
# 1     81.89       11.63
# 2     52.55        2.84
# 3     91.00       10.29
# 4     48.20       19.46

# %%
summary_df.to_csv(r'\Weather_Data_Results.csv')

# %%
#Establish date for dataset
# date_first =summary_df('Date').first()
date_first = summary_df['Date'].iloc[0]
weather_date=time.strftime('%m-%d-%y', time.localtime(date_first))
weather_date
# Out:
# '08-21-19'

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#obtain the x and y coordinates for x and y coordinates

#get limits for x axis
x_limit_min = summary_df["Lat"].min()
# x_limit_min
x_limit_max = summary_df["Lat"].max()
# x_limit_max


#graphing for latitude vs. max temp
#max temp limits
temp_limit_min = summary_df["Max Temp"].min()
# x_limit_min
temp_limit_max = summary_df["Max Temp"].max()
# x_limit_max

#latitude vs. max temp
lat_vs_maxtemp = plt.scatter(summary_df['Lat'], summary_df["Max Temp"], marker="o", facecolors="blue", edgecolors="black",
            s=30, alpha=0.75)
plt.scatter

# Incorporate the other graph properties

# Set your x and y limits
plt.xlim(x_limit_min-5, x_limit_max+5)
plt.ylim(temp_limit_min-5, temp_limit_max+5)

#label x and y axis

plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

#add header
plt.title(f"City Latitude vs. Max Temperature ({weather_date})")

# Set a grid on the plot
plt.grid()

# Save Figure
plt.savefig("City_Lat_vs_MaxTemp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#obtain the x and y coordinates for x and y coordinates

#get limits for x axis
x_limit_min = summary_df["Lat"].min()
# x_limit_min
x_limit_max = summary_df["Lat"].max()
# x_limit_max


#graphing for latitude vs. humidity
#humidity limits
humid_limit_min = summary_df["Humidity"].min()
# humid_limit_min
humid_limit_max = summary_df["Humidity"].max()
# humid_limit_max

#latitude vs. himidity
lat_vs_humidity = plt.scatter(summary_df['Lat'], summary_df["Humidity"], marker="o", facecolors="blue", edgecolors="black",
            s=30, alpha=0.75)
plt.scatter

# Incorporate the other graph properties

# Set your x and y limits
plt.xlim(x_limit_min-5, x_limit_max+5)
plt.ylim(humid_limit_min-5, humid_limit_max+5)

#label x and y axis

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

#add header
plt.title(f"City Latitude vs. Humidity ({weather_date})")

# Set a grid on the plot
plt.grid()

# Save Figure
plt.savefig("City_Lat_vs_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#obtain the x and y coordinates for x and y coordinates

#get limits for x axis
x_limit_min = summary_df["Lat"].min()
# x_limit_min
x_limit_max = summary_df["Lat"].max()
# x_limit_max


#graphing for latitude vs. max temp
#max temp limits
cloud_limit_min = summary_df["Cloudiness"].min()
# cloud_limit_min
cloud_limit_max = summary_df["Cloudiness"].max()
# cloud_limit_max

#latitude vs. cloudiness
lat_vs_cloudiness = plt.scatter(summary_df['Lat'], summary_df["Cloudiness"], marker="o", facecolors="blue", edgecolors="black",
            s=30, alpha=0.75)
plt.scatter

# Incorporate the other graph properties

# Set your x and y limits
plt.xlim(x_limit_min-5, x_limit_max+5)
plt.ylim(cloud_limit_min-5, cloud_limit_max+5)

#label x and y axis

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

#add header
plt.title(f"City Latitude vs. Cloudiness ({weather_date})")

# Set a grid on the plot
plt.grid()

# Save Figure
plt.savefig("City_Lat_vs_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#obtain the x and y coordinates for x and y coordinates

#get limits for x axis
x_limit_min = summary_df["Lat"].min()
# x_limit_min
x_limit_max = summary_df["Lat"].max()
# x_limit_max


#graphing for latitude vs. wind speed
#max temp limits
wind_limit_min = summary_df["Wind Speed"].min()
# wind_limit_min
wind_limit_max = summary_df["Wind Speed"].max()
# wind_limit_max

#latitude vs. wind speed
lat_vs_wind = plt.scatter(summary_df['Lat'], summary_df["Wind Speed"], marker="o", facecolors="blue", edgecolors="black",
            s=30, alpha=0.75)
plt.scatter

# Incorporate the other graph properties

# Set your x and y limits
plt.xlim(x_limit_min-5, x_limit_max+5)
plt.ylim(wind_limit_min-5, wind_limit_max+5)

#label x and y axis

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

#add header
plt.title(f"City Latitude vs. Wind Speed  ({weather_date})")

# Set a grid on the plot
plt.grid()

# Save Figure
plt.savefig("City_Lat_vs_WindSpeed.png")

# Show plot
plt.show()
